# %%
import os
os.getcwd()
# Out:
# '/Users/marcin/Documents/VIMSS/ontology/Sample/sample-annotator/notebooks'

# %%
import sys
sys.path.append(os.path.abspath("/Users/marcin/Documents/VIMSS/ontology/Sample/sample-annotator/sample_annotator"))
#sys.path.append('../sample-annotator')
sys.path
# Out:
# ['/Users/marcin/Documents/VIMSS/ontology/Sample/sample-annotator/notebooks',
#  '/Library/Frameworks/Python.framework/Versions/3.7/lib/python37.zip',
#  '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7',
#  '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/lib-dynload',
#  '',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/xn2v-0.1.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/sklearn-0.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/wrapt-1.12.0-py3.7-macosx-10.9-x86_64.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/wheel-0.34.2-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/termcolor-1.1.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/scipy-1.4.1-py3.7-macosx-10.9-x86_64.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/protobuf-3.11.3-py3.7-macosx-10.9-x86_64.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/opt_einsum-3.1.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/Keras_Preprocessing-1.1.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/Keras_Applications-1.0.8-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/grpcio-1.27.2-py3.7-macosx-10.9-x86_64.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/google_pasta-0.1.8-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/astor-0.8.1-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/absl_py-0.9.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/scikit_learn-0.22.1-py3.7-macosx-10.9-x86_64.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/Werkzeug-1.0.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/setuptools-45.2.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/requests-2.23.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/google_auth-1.11.2-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/google_auth_oauthlib-0.4.1-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/h5py-2.10.0-py3.7-macosx-10.9-x86_64.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/joblib-0.14.1-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/urllib3-1.25.8-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/rsa-4.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/pyasn1_modules-0.2.8-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/requests_oauthlib-1.3.0-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/pyasn1-0.4.8-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/oauthlib-3.1.0-py3.7.egg',
#  '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages',
#  '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Knowledge_Graph_Exchange-0.0.1-py3.7.egg',
#  '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/click-6.7-py3.7.egg',
#  '/Users/marcin/Library/Python/3.7/lib/python/site-packages/IPython/extensions',
#  '/Users/marcin/.ipython',
#  '/Users/marcin/Documents/VIMSS/ontology/Sample/sample-annotator/sample_annotator',
#  '/Users/marcin/Documents/VIMSS/ontology/Sample/sample-annotator/sample_annotator']

# %%
# !pip install git+https://github.com/microbiomedata/sample-annotator.git
# Out:
# Collecting git+https://github.com/microbiomedata/sample-annotator.git
#   Cloning https://github.com/microbiomedata/sample-annotator.git to /private/var/folders/hx/svkm0dlj0bd9689lm21_7fyw0000gs/T/pip-req-build-hhm23tci
#   Running command git clone -q https://github.com/microbiomedata/sample-annotator.git /private/var/folders/hx/svkm0dlj0bd9689lm21_7fyw0000gs/T/pip-req-build-hhm23tci
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/hx/svkm0dlj0bd9689lm21_7fyw0000gs/T/pip-build-env-0qwi3x51/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel
#        cwd: None
#   Complete output (44 lines):
#   Traceback (most recent call last):
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/__main__.py", line 26, in <module>
#       sys.exit(_main())
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_internal/cli/main.py", line 73, in main
#       command = create_command(cmd_name, isolated=("--isolated" in cmd_args))
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_internal/commands/__init__.py", line 104, in create_command
#       module = importlib.import_module(module_path)
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/__init__.py", line 127, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#     File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 726, in exec_module
#     File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_internal/commands/install.py", line 24, in <module>
#       from pip._internal.cli.req_command import RequirementCommand, with_cleanup
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_internal/cli/req_command.py", line 16, in <module>
#       from pip._internal.index.package_finder import PackageFinder
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_internal/index/package_finder.py", line 21, in <module>
#       from pip._internal.index.collector import parse_links
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_internal/index/collector.py", line 14, in <module>
#       from pip._vendor import html5lib, requests
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_vendor/requests/__init__.py", line 114, in <module>
#       from . import utils
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_vendor/requests/utils.py", line 25, in <module>
#       from . import certs
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_vendor/requests/certs.py", line 15, in <module>
#       from pip._vendor.certifi import where
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_vendor/certifi/__init__.py", line 1, in <module>
#       from .core import contents, where
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip/_vendor/certifi/core.py", line 12, in <module>
#       from importlib.resources import read_text
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/resources.py", line 12, in <module>
#       from typing import Iterable, Iterator, Optional, Set, Union   # noqa: F401
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#       class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#     File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#       self._abc_registry = extra._abc_registry
#   AttributeError: type object 'Callable' has no attribute '_abc_registry'
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: /Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/hx/svkm0dlj0bd9689lm21_7fyw0000gs/T/pip-build-env-0qwi3x51/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel Check the logs for full command output.
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from sample_annotator.measurements.measurements import MeasurementEngine
from sample_annotator.report_model import AnnotationReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-39d4c74ed3f1> in <module>
# ----> 1 from sample_annotator.measurements.measurements import MeasurementEngine
#       2 from sample_annotator.report_model import AnnotationReport
#
# ModuleNotFoundError: No module named 'sample_annotator'

# %%
import .

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ -----------
# absl-py                  0.9.0
# antlr4-python3-runtime   4.9.2
# appdirs                  1.4.4
# appnope                  0.1.0
# argh                     0.26.2
# astor                    0.8.1
# astunparse               1.6.3
# attrs                    21.2.0
# backcall                 0.1.0
# bcp47                    0.0.4
# beautifulsoup4           4.9.3
# bioregistry              0.2.5
# biothings-client         0.2.0
# bleach                   3.0.2
# bokeh                    2.0.2
# cache-decorator          1.2.5
# cachetools               4.2.2
# cachier                  1.2.5
# catboost                 0.24.4
# certifi                  2021.5.30
# cffi                     1.14.5
# CFGraph                  0.2.1
# chardet                  4.0.0
# click                    7.1.2
# cloudpickle              1.4.1
# colorama                 0.4.4
# colorcet                 2.0.2
# compress-json            1.0.3
# compress-pickle          1.1.1
# cycler                   0.10.0
# dask                     2.18.1
# datashader               0.11.0
# datashape                0.5.2
# deap                     1.3.1
# decorator                4.3.0
# defusedxml               0.5.0
# Deprecated               1.2.12
# dict-hash                1.1.0
# dill                     0.3.3
# distlib                  0.3.2
# distributed              2.18.0
# distro                   1.5.0
# docopt                   0.6.2
# downloaders              1.0.12
# encodeproject            1.0.17
# ensmallen-graph          0.5.2
# entrypoints              0.2.3
# env                      0.1.0
# et-xmlfile               1.0.1
# filelock                 3.0.12
# frozendict               2.0.3
# fsspec                   0.7.4
# funowl                   0.1.6
# future                   0.18.2
# gast                     0.3.3
# ghp-import               2.0.1
# google-auth              1.11.2
# google-auth-oauthlib     0.4.1
# google-pasta             0.1.8
# googlemaps               4.4.5
# graphviz                 0.16
# greenlet                 1.1.0
# grpcio                   1.27.2
# h5py                     2.10.0
# hbreader                 0.9.1
# hdmf                     1.2.0
# HeapDict                 1.0.1
# holoviews                1.13.2
# html3                    1.17
# humanize                 2.4.0
# idna                     2.10
# imageio                  2.9.0
# importlib-metadata       4.6.1
# inflect                  5.3.0
# ipykernel                5.1.0
# ipython                  7.2.0
# ipython-genutils         0.2.0
# ipywidgets               7.4.2
# isodate                  0.6.0
# jdcal                    1.4.1
# jedi                     0.13.1
# Jinja2                   2.10
# joblib                   0.14.1
# jsobject                 0.10.2
# jsonasobj                2.0.2.dev4
# jsonasobj2               1.0.4
# jsonschema               2.6.0
# jupyter                  1.0.0
# jupyter-client           5.2.3
# jupyter-console          6.0.0
# jupyter-core             4.4.0
# Keras                    2.4.3
# Keras-Applications       1.0.8
# Keras-Preprocessing      1.1.0
# kiwisolver               1.2.0
# Knowledge-Graph-Exchange 0.0.1
# linkml                   1.0.1
# linkml-model             1.0.1
# linkml-runtime           1.0.10
# llvmlite                 0.33.0
# locket                   0.2.0
# lxml                     4.6.3
# Markdown                 3.3.4
# MarkupSafe               1.1.0
# marshmallow              3.0.0b3
# matplotlib               3.2.1
# mergedeep                1.3.4
# mistune                  0.8.4
# mkdocs                   1.2.1
# more-click               0.0.5
# more-itertools           8.8.0
# msgpack                  1.0.0
# MulticoreTSNE            0.1
# multipledispatch         0.6.0
# mvp-module-library       0.0.1
# mygene                   3.1.0
# nbconvert                5.4.0
# nbformat                 4.4.0
# networkx                 2.2
# nmdc-schema              2021.7.1rc1
# nose                     1.3.7
# notebook                 5.7.2
# num2words                0.5.10
# numba                    0.50.0
# numpy                    1.21.0
# oauthlib                 3.1.0
# obonet                   0.2.5
# ontobio                  1.7.2
# opencv-python            4.4.0.46
# openpyxl                 3.0.3
# opt-einsum               3.1.0
# packaging                21.0
# pandas                   1.1.5
# pandocfilters            1.4.2
# panel                    0.9.5
# param                    1.9.3
# parse                    1.19.0
# parso                    0.3.1
# partd                    1.1.0
# pathtools                0.1.2
# pbr                      5.4.5
# pexpect                  4.6.0
# pickleshare              0.7.5
# Pillow                   7.1.2
# Pint                     0.17
# pip                      20.1.1
# pipenv                   2021.5.29
# plotly                   4.14.1
# pluggy                   1.0.0.dev0
# portalocker              1.4.0
# prefixcommons            0.1.9
# prologterms              0.0.6
# prometheus-client        0.5.0
# prompt-toolkit           2.0.7
# protobuf                 3.11.3
# psutil                   5.7.0
# ptyprocess               0.6.0
# pyarrow                  3.0.0
# pyasn1                   0.4.8
# pyasn1-modules           0.2.8
# pycparser                2.20
# pyct                     0.4.6
# pydantic                 1.8.2
# pydotplus                2.0.2
# Pygments                 2.3.0
# PyJSG                    0.11.6
# PyLDmod                  2.0.5
# pynwb                    1.1.0
# pyparsing                3.0.0b2
# pyrsistent               0.18.0
# PyShEx                   0.7.20
# PyShExC                  0.8.3
# pysolr                   3.8.1
# pystow                   0.1.7
# python-dateutil          2.7.5
# pytz                     2021.1
# pyviz-comms              0.7.5
# PyWavelets               1.1.1
# PyYAML                   5.4.1
# pyyaml-env-tag           0.1
# pyzmq                    17.1.2
# qtconsole                4.4.3
# quantulum3               0.7.7
# rdflib                   5.0.0
# rdflib-jsonld            0.5.0
# requests                 2.23.0
# requests-oauthlib        1.3.0
# retrying                 1.3.3
# rsa                      4.0
# ruamel.yaml              0.16.12
# ruamel.yaml.clib         0.2.2
# RutishauserLabtoNWB      1.1.0
# scikit-image             0.17.2
# scikit-learn             0.22.1
# scipy                    1.4.1
# seaborn                  0.11.1
# Send2Trash               1.5.0
# setuptools               45.2.0
# shap                     0.39.0
# ShExJSG                  0.7.0
# six                      1.16.0
# sklearn                  0.0
# slicer                   0.0.7
# sortedcontainers         2.2.2
# sparql-slurper           0.3.4
# SPARQLWrapper            1.8.2
# stopit                   1.1.2
# tabula-py                2.1.0
# tbb                      2019.0
# tblib                    1.6.0
# tensorboard              2.2.2
# tensorboard-plugin-wit   1.7.0
# tensorflow               2.2.0
# tensorflow-estimator     2.2.0
# termcolor                1.1.0
# terminado                0.8.1
# testpath                 0.4.2
# tifffile                 2020.7.4
# toml                     0.10.2
# toolz                    0.10.0
# torch                    1.5.1
# tornado                  5.1.1
# tox                      4.0.0a6
# TPOT                     0.11.5
# tqdm                     4.46.0
# traitlets                4.3.2
# typing                   3.6.6
# typing-extensions        3.10.0.0
# umap-learn               0.4.4
# update-checker           0.17
# urllib3                  1.25.8
# virtualenv               20.4.7
# virtualenv-clone         0.5.4
# watchdog                 0.9.0
# wcwidth                  0.1.7
# webencodings             0.5.1
# Werkzeug                 1.0.0
# wget                     3.2
# wheel                    0.34.2
# widgetsnbextension       3.4.2
# wrapt                    1.12.0
# xarray                   0.15.1
# xlrd                     1.2.0
# xn2v                     0.1.0
# yamldown                 0.1.6
# zict                     2.0.0
# zipp                     3.5.0
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.

# %%
def test_salinity(self):
    tsv_file = open("./tests/inputs/salinity_summary.tsv")
    salinity_data = csv.reader(tsv_file, delimiter="\t")

    report = AnnotationReport(messages=[])
    m = MeasurementEngine()

    for row in salinity_data:
        print(row)

        qv = m.repair(row[1], report=report)
        print(qv)
